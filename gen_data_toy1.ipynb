# %% [markdown]
# # Generación de dataset

# %%
from drawdata import ScatterWidget

# %%
widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
df = widget.data_as_pandas[["x","y","label"]]
df.head()
# Out:
#            x          y label
# 0  14.728736  59.704260     a
# 1  27.951304  28.548151     a
# 2  -0.293835  47.542074     a
# 3   8.647573  51.429292     a
# 4   8.317275  41.214211     a

# %%
df.columns = ["x1","x2","y"]

# %%
df.head()
# Out:
#           x1         x2  y
# 0  14.728736  59.704260  a
# 1  27.951304  28.548151  a
# 2  -0.293835  47.542074  a
# 3   8.647573  51.429292  a
# 4   8.317275  41.214211  a

# %%
df_y = df.groupby("y")["y"].count()
df_y
# Out:
# y
# a    160
# b    161
# c    246
# d    177
# Name: y, dtype: int64

# %%
ax = df_y.plot(kind="bar", title="Numero de valores por clases")
ax.set_xlabel("Clase")
ax.set_ylabel("Numero de valores")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.grid(ls=":")

# %%
label2num = {'a':0, 'b':1, 'c':2, 'd':3}
num2label = {0:'a', 1:'b', 2:'c', 3:'d'}

# %%
df["y"] = df["y"].map(label2num)
df.head()
# Out:
#           x1         x2  y
# 0  14.728736  59.704260  0
# 1  27.951304  28.548151  0
# 2  -0.293835  47.542074  0
# 3   8.647573  51.429292  0
# 4   8.317275  41.214211  0

# %%
import seaborn as sb

sb.scatterplot(data=df, x="x1", y="x2", hue="y", palette="Set1")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
df.to_csv("data.csv", index=False)
